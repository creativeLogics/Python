# %% [markdown]
# # Question 1:
# # Define Object Oriented Programming Language?
# # Answer :
# Object-oriented programming: As the name suggests, Object-Oriented Programming or OOPs refers to languages that uses objects in programming. Object-oriented programming aims to implement real-world entities like inheritance, hiding, polymorphism etc in programming. The main aim of OOP is to bind together the data and the functions that operate on them so that no other part of the code can access this data except that function.
# OOPs Concepts:
# 1) Polymorphism
# 2) Inheritance
# 3) Inheritance
# 4) Ecapsulation
# 5) Abstraction
# Class Object Method Message Passing.

# %% [markdown]
# # Question 2:
# # List down the Benefits of OOP?
# # Answer :
#
# 1: OOP provides a clear modular structure for programs.
# 2: It is good for defining abstract data types.
# 3: Implementation details are hidden from other modules and other modules has a clearly defined interface.
# 4: It is easy to maintain and modify existing code as new objects can be created with small differences to existing ones.
# 5: objects, methods, instance, message passing, inheritance are some important properties provided by these particular languages
# 6: encapsulation, polymorphism, abstraction are also counts in these fundamentals of programming language.
# 7: It implements real life scenario.
# 8: In OOP, programmer not only defines data types but also deals with operations applied for data structures.

# %% [markdown]
# # Question 3:
# # Differentiate between function and method?
# # Answer:
#  FUNCTION: A function is a piece of code that is called by name. It can be passed data to operate on (i.e. the parameters) and can optionally return data (the return value). All data that is passed to a function is explicitly passed.
#
#  METHOD: A method is a piece of code that is called by a name that is associated with an object. In most respects it is identical to a function except for two key differences:
#
# 1) A method is implicitly passed the object on which it was called.
# 2) A method is able to operate on data that is contained within the class (remembering that an object is an instance of a class - the class is the definition, the object is an instance of that data).

# %% [markdown]
# # Question 4:
# # Define the following terms:
# # 1. Class
# # 2. Object
# # 3. Attribute
# # 4. Behavior.
# # Answer:
#
# # 1. CLASS :
#               A user-defined prototype for an object that defines a set of attributes that characterize any object of the class. The attributes are data members (class variables and instance variables) and methods, accessed via dot notation.
#
# # 2. Object :
#              A unique instance of a data structure that's defined by its class. An object comprises both data members (class variables and instance variables) and methods.
#
# # 3. Attribute :
#                 A variable stored in an instance or class is called an attribute.
#
# # 4. Behavior :
#                 Behaviors are actions that can occur on an object. The behaviors that can be performed on a specific class of object are called methods.

# %%
# Question 5:
# Write a code in python in which create a class named it Car which have 5 attributes such like (model, color and name etc.)
# and 3 methods. And create 5 object instance from that class.
# Answer:
class Car:
    def __init__(self, name, color, brand):
        self.name= name
        self.model= "2019"
        self.color= color
        self.brand= brand
        self.transmition= "manual";
        
    def checkSpec(self):
        print("Car Name:", self.name,"\n")
        print("Car model:", self.model,"\n")
        print('Color:', self.color,"\n")
        print("Brand name:", self.brand,"\n")
        print("Transmition", self.transmition, "\n")
    
    def updateAndCheckSpec(self, model, transmition):
        print("Specification Changed \n")
        self.model= model
        self.transmition= transmition
        self.checkSpec()
        
    def changeAndCheckBrand(self, brand):
        print("Brand Changed \n")
        self.brand= brand
        self.checkSpec()
        
print("\n         My First Car \n")
car1= Car('Mehran', 'Black', 'Suzuki')
car1.checkSpec()
car1.updateAndCheckSpec("2020", "Auto")
car1.changeAndCheckBrand("Nissan")

print("\n         My Second Car \n")
car2= Car('Aqua', 'Blue', 'Toyota')
car2.checkSpec()
car2.updateAndCheckSpec("2020", "Auto")
car2.changeAndCheckBrand("Suzuki")

print("\n         My Third Car \n")
car3= Car('Alto', 'Red', 'Suzuki')
car3.checkSpec()
car3.updateAndCheckSpec("2020", "Auto")
car3.changeAndCheckBrand("Toyota")

print("\n         My Fourth Car \n")
car4= Car('Juke', 'Golden', 'Nissan')
car4.checkSpec()
car4.updateAndCheckSpec("2020", "Auto")
car4.changeAndCheckBrand("Kia")

print("\n         My Fifth Car \n")
car5= Car('Corolla', 'Silver', 'Toyota')
car5.checkSpec()
car5.updateAndCheckSpec("2020", "Auto")
car5.changeAndCheckBrand("Nissan")

print("Insha Allah In future")
# Out:
#          My First Car
#
# Car Name: Mehran
#
# Car model: 2019
#
# Color: Black
#
# Brand name: Suzuki
#
# Transmition manual
#
# Specification Changed
#
# Car Name: Mehran
#
# Car model: 2020
#
# Color: Black
#
# Brand name: Suzuki
#
# Transmition Auto
#
# Brand Changed
#
# Car Name: Mehran
#
# Car model: 2020
#
# Color: Black
#
# Brand name: Nissan
#
# Transmition Auto
#
#
#          My Second Car
#
# Car Name: Aqua
#
# Car model: 2019
#
# Color: Blue
#
# Brand name: Toyota
#
# Transmition manual
#
# Specification Changed
#
# Car Name: Aqua
#
# Car model: 2020
#
# Color: Blue
#
# Brand name: Toyota
#
# Transmition Auto
#
# Brand Changed
#
# Car Name: Aqua
#
# Car model: 2020
#
# Color: Blue
#
# Brand name: Suzuki
#
# Transmition Auto
#
#
#          My Third Car
#
# Car Name: Alto
#
# Car model: 2019
#
# Color: Red
#
# Brand name: Suzuki
#
# Transmition manual
#
# Specification Changed
#
# Car Name: Alto
#
# Car model: 2020
#
# Color: Red
#
# Brand name: Suzuki
#
# Transmition Auto
# ...
