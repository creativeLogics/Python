# %%
# Question:1
# Write a Python function to calculate the factorial of a number (a non-negative
# integer). The function accepts the number as an argument.
# Answer :
def factorial_func(num):
    if(num == 0):
        return 1;
    else:
        return num * factorial_func(num-1);
val= factorial_func(int(input("Write a number for factorial number : ")))
print(val)
# Out:
# Write a number for factorial number : 4
# 24

# %%
# Question:2
# Write a Python function that accepts a string and calculate the number of upper
# case letters and lower case letters.
# Answer :
def str_test(str_input):
    result= {'upperCase': 0, 'lowerCase': 0};
    for val in str_input :
        if val.isupper() :
            result['upperCase']+= 1;
        elif val.islower() :
            result['lowerCase']+= 1;
        else:
            pass;
    print("Original String :", str_input)
    print("Number of UPPER CASE letters :", result['upperCase'])
    print("Number of LOWER CASE letters :", result['lowerCase'])
    
userInput= input("Write a paragraph to count upper case and lower case letters : ")
str_test(userInput)
# Out:
# Write a paragraph to count upper case and lower case letters : Write a paragraph to count upper case and lower case letters
# Original String : Write a paragraph to count upper case and lower case letters
# Number of UPPER CASE letters : 1
# Number of LOWER CASE letters : 49

# %%
# Question:3
# Write a Python function to print the even numbers from a given list.
# Answer :
def list_test(myList):
    result= [];
    for val in myList:
        if val % 2 == 0:
            result.append(val)
        else:
            continue;
    print("Even numbers are:", result);
    
myList= [2, 4, 3, 7, 13, 18, 22 , 23, 52];
list_test(myList)
# Out:
# Even numbers are: [2, 4, 18, 22, 52]

# %%
# Question:4
# Write a Python function that checks whether a passed string is palindrome or not.
# Note: A palindrome is a word, phrase, or sequence that reads the same
# backward as forward, e.g., madam
# Answer :
# Method 1
def is_palindrome(userInput):
    left_position= 0;
    right_position= len(userInput) - 1;
    while right_position >= left_position:
        if userInput[left_position] != userInput[right_position]:
            return False;
        left_position+= 1;
        right_position-= 1;
    return True;
    
result1= 'madam'
if is_palindrome(result1)== True :
    print(result1, 'value is palindrome')
else :
    print(result1, 'value is not palindrome')
    
    
# Method 2
def is_palindrome2(val):
    if val[::-1] == val:
        return True;
    else :
        return False;
    
result2= 'check'
if is_palindrome2(result2)== True :
    print(result2, 'value is palindrome')
else :
    print(result2, 'value is not palindrome')
    
result3= 'madam'
if is_palindrome2(result3)== True :
    print(result3, 'value is palindrome')
else :
    print(result3, 'value is not palindrome')
# Out:
# madam value is palindrome
# check value is not palindrome
# madam value is palindrome

# %%
# Question:5
# Write a Python function that takes a number as a parameter and check the
# number is prime or not.
# Answer :
def prime_test(num):
    # If given number is greater than 1 
    if num > 1: 
      
       # Iterate from 2 to n / 2  
       for i in range(2, num//2): 
           # If num is divisible by any number between  
           # 2 and n / 2, it is not prime  
           if (num % i) == 0: 
               print(num, "is not a prime number") 
               break
       else: 
           print(num, "is a prime number") 
  
    else: 
       print(num, "is not a prime number") 
    
num = int(input("Your number"));
prime_test(num)
# Out:
# Your number11
# 11 is a prime number

# %%
# Question: 6
# Suppose a customer is shopping in a market and you need to print all the items
# which user bought from market.
# Answer :
while True:  
    try: 
        bg = float(input("Enter your budget : ")) 
        budget = bg
    except ValueError: 
        print("PRINT NUMBER AS A AMOUNT") 
        continue
    else:
        break
  
# dictionary to store product("name"), quantity("quant"),  
# price("price") with empty list as their values 
items ={"name":[], "quant":[], "price":[]} 
  
# convert dictionary to list for more updation 
itemsList = list(items.values())
  
# variable name value of "name" from dictionary 'items' 
name = itemsList[0] 
  
# variable quant value of "quant" from dictionary 'items'
quant = itemsList[1]
  
# variable price value of "price" from dictionary 'items'
price = itemsList[2]
  
# This loop terminates when user select 2.EXIT option when asked 
# in try it will ask user for an option as an integer (1 or 2)  
# if correct then proceed else continue asking options 
while True: 
    try: 
        userChoice = int(input("1.ADD\n2.EXIT\nEnter your choice : ")) 
    except ValueError: 
        print("\nERROR: Choose only digits from the given option") 
        continue
    else: 
        # check the budget is greater than zero and option selected 
        # by user is 1 i.e. to add an item 
        if userChoice == 1 and budget >0:        
   
            # input products name             
            pName = input("Enter product name : ")  
            # input quantity of product 
            pQuant = input("Enter quantity : ") 
            # input price of the product 
            pPrice = float(input("Enter price of the product : "))   
  
            if pPrice > budget: 
                # check if price is less than budget 
                print("\nSorry, you budget is to low for purchase product")
                continue
  
            else: 
                # checks if product name already in list 
                if pName in name:
                    # find the index of that product 
                    ind = name.index(pName)   
  
                    # remove quantity from "quant"  index of the product 
                    quant.remove(pQuant[ind])  
  
                    # remove price from "price" index of the product 
                    price.remove(pPrice[ind])   
  
                    # insert new value given by user earlier 
                    quant.insert(ind, pQuant)  
  
                    # insert new value given by user earlier 
                    price.insert(ind, pPrice*int(pQuant))    
  
                    # subtracting the price from the budget and assign 
                    # it to 'budget' sum(price) is because price = [100, 200] if  
                    # budget is 500 then budget = bg-sum(price) = 200 
                    # after updating for same product at index 0 let 
                    # price = [200, 200] so budget = 100 
                    budget = bg-sum(price)    
  
                    print("\namount left", budget) 
                else: 
                    # append value of in "name", "quantity", "price" 
                    name.append(pName)   
   
                    # as name = itmesList[0] it will append all the value in the 
                    # list eg: "name":["rice"] 
                    # same for quantity and price 
                    quant.append(pQuant)    
  
                    # same for quantity and price 
                    price.append(pPrice*int(pQuant))     
                    
                    # after appending new value the sum in price 
                    # as to be calculated
                    budget = bg-sum(price)
  
                    print("\namount left", budget) 
  
        # if budget goes zero print "NO BUDGET" 
        elif budget<= 0: 
            print("\nNO BUDGET")  
        else: 
            break 
  
# will print amount left in variable 'budget' 
print("\nAmount left : Rs.", budget) 
  
print("\n\n\nGROCERY LIST") 
  
# Write a function which accepts the multiple arguments of user shopping list and
# print all the items which user bought from market.
# Answer :
def shoping_list(itemsList):
    
    name= itemsList[0]
    quant= itemsList[1]
    price= itemsList[2]
    for i in range(len(name)):
        # print final shopping list
        print('\n',name[i], quant[i], price[i],'\n')

# Calling function for print shopping list
shoping_list(itemsList)
# Out:
# Enter your budget : 500
# 1.ADD
# 2.EXIT
# Enter your choice : 1
# Enter product name : Rice
# Enter quantity : 2
# Enter price of the product : 120
#
# amount left 260.0
# 1.ADD
# 2.EXIT
# Enter your choice : 1
# Enter product name : Apple Juice
# Enter quantity : 2
# Enter price of the product : 25
#
# amount left 210.0
# 1.ADD
# 2.EXIT
# Enter your choice : 1
# Enter product name : dairy milk chocolate
# Enter quantity : 2
# Enter price of the product : 25
#
# amount left 160.0
# 1.ADD
# 2.EXIT
# Enter your choice : 2
#
# Amount left : Rs. 160.0
#
#
#
# GROCERY LIST
#
#  Rice 2 240.0
#
#
#  Apple Juice 2 50.0
#
#
#  dairy milk chocolate 2 50.0
